# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install StyleGan2 repo
# Only run this once! Skip this after running it once.

# %%
# %cd /content/drive/My\ Drive/Capstone
# !mkdir stylegan2-contentgen
# %cd stylegan2-contentgen/
# !git clone https://github.com/dvschultz/stylegan2
# %cd stylegan2
# !mkdir pkl
# %cd pkl
# !gdown --id 1JLqXE5bGZnlu2BkbLPD5_ZxoO3Nz-AvF 
# %cd ../
# !mkdir results
# !mkdir results/00001-pretrained
# %cd results/00001-pretrained
# !gdown --id 1UlDmJVLLnBD9SnLSMXeiZRO6g-OMQCA_
# !mv stylegan2-ffhq-config-f.pkl network-snapshot-10000.pkl
# %cd ../../
# %mkdir datasets
# Out:
# /content/drive/My Drive/Capstone
# /content/drive/My Drive/Capstone/stylegan2-contentgen
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 549, done.
# remote: Total 549 (delta 0), reused 0 (delta 0), pack-reused 549
# Receiving objects: 100% (549/549), 22.46 MiB | 14.06 MiB/s, done.
# Resolving deltas: 100% (286/286), done.
# /content/drive/My Drive/Capstone/stylegan2-contentgen/stylegan2
# /content/drive/My Drive/Capstone/stylegan2-contentgen/stylegan2/pkl
# Downloading...
# From: https://drive.google.com/uc?id=1JLqXE5bGZnlu2BkbLPD5_ZxoO3Nz-AvF
# To: /content/drive/My Drive/Capstone/stylegan2-contentgen/stylegan2/pkl/inception_v3_features.pkl
# 87.3MB [00:00, 122MB/s]
# /content/drive/My Drive/Capstone/stylegan2-contentgen/stylegan2
# /content/drive/My Drive/Capstone/stylegan2-contentgen/stylegan2/results/00001-pretrained
# Downloading...
# From: https://drive.google.com/uc?id=1UlDmJVLLnBD9SnLSMXeiZRO6g-OMQCA_
# ...

# %% [markdown]
# ## Picking up from a previous session

# %%
#Run this when rerunning notebooks
# %cd /content/drive/My\ Drive/Capstone/stylegan2-contentgen/stylegan2
# !git pull
# Out:
# /content/drive/My Drive/Capstone/stylegan2-contentgen/stylegan2
# Already up to date.

# %% [markdown]
# ## Tensorflow version 1.15

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# ## Convert Images

# %%
# !python dataset_tool.py create_from_images ./datasets/faces /content/drive/My\ Drive/Datasets/faces
# Out:
# Loading images from "/content/drive/My Drive/Datasets/faces"
# 100% 263/263 [05:59<00:00,  1.37s/it]

# %% [markdown]
# # Training

# %%
ls
# Out:
# datasets/               results/
# dataset_tool.py         run_generator.py
# dnnlib/                 run_metrics.py
# Dockerfile              run_projector.py
# docs/                   run_training.py
# easy-install.sh         runway_model.py
# LICENSE.txt             runway.yml
# metrics/                StyleGAN2_Google_Colab_Example.ipynb
# pkl/                    StyleGAN2_projection_interpolation.ipynb
# pretrained_networks.py  StyleGAN2_Projection.ipynb
# projector.py            test_nvcc.cu
# README.md               training/
# requirements.txt        USAGE.md

# %%
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-f --dataset=faces --mirror-augment=true --metrics=None
# Out:
# Local submit - run_dir: results/00003-stylegan2-faces-1gpu-config-f
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x7d66000 @  0x7fa70f2c5001 0x7fa70bd51765 0x7fa70bdb5bb0 0x7fa70bdb7a4f 0x7fa70be4e048 0x50a7f5 0x50cfd6 0x507f24 0x509202 0x594b01 0x54a17f 0x5517c1 0x59fe1e 0x50d596 0x507f24 0x588fac 0x59fe1e 0x50d596 0x507f24 0x588fac 0x59fe1e 0x50d596 0x509918 0x50a64d 0x50c1f4 0x509918 0x50a64d 0x50c1f4 0x507f24 0x588fac 0x59fe1e
# tcmalloc: large alloc 4294967296 bytes == 0x7fa53dac6000 @  0x7fa70f2c31e7 0x7fa70bd515e1 0x7fa70bdb5c78 0x7fa70bdb5f37 0x7fa70be4df28 0x50a7f5 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x509918 0x50a64d 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24
# ...

# %% [markdown]
# # Generate Images

# %%
# !pip install opensimplex

# %%
ls
# Out:
# datasets/               results/
# dataset_tool.py         run_generator.py
# dnnlib/                 run_metrics.py
# Dockerfile              run_projector.py
# docs/                   run_training.py
# easy-install.sh         runway_model.py
# LICENSE.txt             runway.yml
# metrics/                StyleGAN2_Google_Colab_Example.ipynb
# pkl/                    StyleGAN2_projection_interpolation.ipynb
# pretrained_networks.py  StyleGAN2_Projection.ipynb
# projector.py            test_nvcc.cu
# README.md               training/
# requirements.txt        USAGE.md

# %%
# /content/drive/My Drive/Capstone/stylegan2-contentgen/stylegan2/results/00003-stylegan2-faces-1gpu-config-f/network-snapshot-010065.pkl

# %%
# !python run_generator.py generate-images --network=/content/drive/My\ Drive/Capstone/stylegan2-contentgen/stylegan2/results/00003-stylegan2-faces-1gpu-config-f/network-snapshot-010065.pkl --seeds=1-15000 --truncation-psi=0.7
# Out:
# Streaming output truncated to the last 5000 lines.
# Generating image for seed 10003 (10003/15000) ...
# Generating image for seed 10004 (10004/15000) ...
# Generating image for seed 10005 (10005/15000) ...
# Generating image for seed 10006 (10006/15000) ...
# Generating image for seed 10007 (10007/15000) ...
# Generating image for seed 10008 (10008/15000) ...
# Generating image for seed 10009 (10009/15000) ...
# Generating image for seed 10010 (10010/15000) ...
# Generating image for seed 10011 (10011/15000) ...
# Generating image for seed 10012 (10012/15000) ...
# Generating image for seed 10013 (10013/15000) ...
# Generating image for seed 10014 (10014/15000) ...
# Generating image for seed 10015 (10015/15000) ...
# Generating image for seed 10016 (10016/15000) ...
# Generating image for seed 10017 (10017/15000) ...
# Generating image for seed 10018 (10018/15000) ...
# Generating image for seed 10019 (10019/15000) ...
# Generating image for seed 10020 (10020/15000) ...
# ...

# %% [markdown]
# # Interpolation

# %%
# !python run_generator.py generate-latent-walk --network=/content/network-snapshot-010065.pkl --seeds=14961,14950,14936,14869,14910,14961 --frames 200 --truncation-psi=0.7
# Out:
# Local submit - run_dir: results/00006-generate-latent-walk
# dnnlib: Running run_generator.generate_latent_walk() on localhost...
# Loading networks from "/content/network-snapshot-010065.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Loading... Done.
# not enough values to generate walk
# Generating image for step 0/205 ...
# Generating image for step 1/205 ...
# Generating image for step 2/205 ...
# Generating image for step 3/205 ...
# Generating image for step 4/205 ...
# Generating image for step 5/205 ...
# Generating image for step 6/205 ...
# Generating image for step 7/205 ...
# Generating image for step 8/205 ...
# Generating image for step 9/205 ...
# Generating image for step 10/205 ...
# Generating image for step 11/205 ...
# Generating image for step 12/205 ...
# Generating image for step 13/205 ...
# Generating image for step 14/205 ...
# ...

# %% [markdown]
# # Generate Latent Walk

# %%
# !ffmpeg -r 24 -i /content/drive/My\ Drive/Capstone/stylegan2-contentgen/stylegan2/results/00006-generate-latent-walk/frame%05d.png -vcodec libx264 -pix_fmt yuv420p latent-walk.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...
